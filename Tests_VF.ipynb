# %% [raw]
# # this repo branch has APFrequencyTest
# !pip install --upgrade git+https://github.com/appukuttan-shailesh/hippounit@add_AP_freq_test
# #!ls /opt/app-root/src/.local/lib/python3.8/site-packages/hippounit/tests/

# %% [raw]
# # this repo has pickle fix
# !pip install git+https://github.com/appukuttan-shailesh/hbp-validation-client

# %%
import os
import zipfile
from hbp_validation_framework import ModelCatalog, utils
mc = ModelCatalog()

# %%
model_alias = "ventral_CA1_pyramidal_neuron_ADmice"
list_model_version = ["WT_3m", "WT_8m", "Tg_3m", "Tg_8m"]
# list_model_version = ["WT_8m", "Tg_3m", "Tg_8m"]
dict_test_alias = {
                    "WT_3m" : ["fi_wt_3months", "hippo_ca1_depolblock"],
                    "WT_8m" : ["fi_wt_8months", "hippo_ca1_depolblock"],
                    "Tg_3m" : ["fi_tg_3months", "hippo_ca1_depolblock"],
                    "Tg_8m" : ["fi_tg_8months", "hippo_ca1_depolblock"],
                  }
                   
base_dir = os.getcwd()

# %%
# download all required models (takes time on Collaboratory, so keeping outside main loop)
for model_version in list_model_version:
    zip_path = mc.download_model_instance(alias=model_alias, version=model_version, overwrite=True)
    with zipfile.ZipFile(zip_path.decode("utf-8")) as zf:
        zf.extractall()

# %%
for model_version in list_model_version:
    # running each model inside separate processes to ensure isolation
    pid = os.fork()
    
    if pid == 0:
        # child process
        model_path = os.path.join(base_dir, model_version)
        os.chdir(model_path)
        from sciunit_wrapper import ModelLoader
        model = ModelLoader(name=model_version, hoc_path="./modeldb_ventralAD/mosinit.hoc", mod_files_path="./modeldb_ventralAD/")
        model.model_alias = model_alias
        model.model_version = model_version
        # print(model.name)
        # print(model)
        # print(os.getcwd())

        for test_alias in dict_test_alias[model_version]:
            result, score = utils.run_test(username="shailesh", 
                                           model=model, 
                                           test_alias=test_alias, 
                                           storage_collab_id="model-validation",
                                           register_result=True)
            # print(result["id"] if result else None)
            print("https://model-catalog.brainsimulation.eu/#result_id." + result["id"] if result else None)
            print(score)
    else:
        # parent process
        os.wait()     

print("====================== Completed ======================")
# Out:
# ----------------------------------------------
# Test name:  AP Frequency test
# Test type:  <class 'hippounit.tests.test_APFrequency.APFrequencyTest'>
# ----------------------------------------------
# ----------------------------------------------
# Model name:  WT_8m
# Model type:  <class 'sciunit_wrapper.ModelLoader'>
# ----------------------------------------------
# ----------------------------------------------
# Score:  1.0082025253072306
# Output files:
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.2nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.15nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.1nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.05nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.0nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.05nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.1nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.15nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.2nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.25nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.3nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.35nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.4nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.45nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.5nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.55nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.6nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_fI_plot.pdf
# ./validation_results/results/ap_freq/current_amps_spikecounts.json
# ./validation_results/results/ap_freq/ap_freq_summary.json
# ./validation_results/results/ap_freq/test_log.txt
# ----------------------------------------------
# Result registered successfully!
# 502c5c62-2e09-4f85-81fb-9ba565075d59
# 1.01
# ----------------------------------------------
# Test name:  Depolarization block test
# Test type:  <class 'hippounit.tests.test_DepolarizationBlockTest.DepolarizationBlockTest'>
# ----------------------------------------------
# ----------------------------------------------
# Model name:  WT_8m
# Model type:  <class 'sciunit_wrapper.ModelLoader'>
# ----------------------------------------------
# The figures are saved in the directory:  ./validation_results/figs/depol_block/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.30000000000000004 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.30000000000000004 nA
# Veq (the equilibrium value during the depolarization block): -22.230762400438763 mV
# Results are saved in the directory:  ./validation_results/results/depol_block/
# ----------------------------------------------
# Score:  2.4185527058393372
# Output files:
# ./validation_results/figs/depol_block/number_of_APs.pdf
# ./validation_results/figs/depol_block/somatic_resp_at_I_maxNumAP.pdf
# ./validation_results/figs/depol_block/somatic_resp_depol_block.pdf
# ./validation_results/figs/depol_block/somatic_resp_at_highest_amp.pdf
# ./validation_results/figs/depol_block/Ith.pdf
# ./validation_results/figs/depol_block/Veq.pdf
# ./validation_results/figs/depol_block/num_of_APs_at_Ith.pdf
# ./validation_results/figs/depol_block/Errors.pdf
# ./validation_results/results/depol_block/depol_block_model_errors.json
# ./validation_results/results/depol_block/depol_block_model_features.json
# ./validation_results/results/depol_block/depol_block_final_score.json
# ./validation_results/results/depol_block/test_log.txt
# ----------------------------------------------
# Result registered successfully!
# 5332923f-7ef4-4b18-bb89-6308f71baf1e
# ZScore_avg+penalty = 2.42
# ----------------------------------------------
# Test name:  AP Frequency test
# Test type:  <class 'hippounit.tests.test_APFrequency.APFrequencyTest'>
# ----------------------------------------------
# ----------------------------------------------
# Model name:  Tg_3m
# Model type:  <class 'sciunit_wrapper.ModelLoader'>
# ----------------------------------------------
# ----------------------------------------------
# Score:  1.8349110570371319
# Output files:
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.2nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.15nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.1nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.05nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.0nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.05nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.1nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.15nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.2nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.25nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.3nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.35nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.4nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.45nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.5nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.55nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.6nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_fI_plot.pdf
# ./validation_results/results/ap_freq/current_amps_spikecounts.json
# ./validation_results/results/ap_freq/ap_freq_summary.json
# ./validation_results/results/ap_freq/test_log.txt
# ----------------------------------------------
# Result registered successfully!
# 73a5b0f3-f909-464f-b602-4333da9ee410
# 1.83
# ----------------------------------------------
# Test name:  Depolarization block test
# Test type:  <class 'hippounit.tests.test_DepolarizationBlockTest.DepolarizationBlockTest'>
# ----------------------------------------------
# ----------------------------------------------
# Model name:  Tg_3m
# Model type:  <class 'sciunit_wrapper.ModelLoader'>
# ----------------------------------------------
# The figures are saved in the directory:  ./validation_results/figs/depol_block/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.2 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.2 nA
# Veq (the equilibrium value during the depolarization block): -22.255491478433264 mV
# Results are saved in the directory:  ./validation_results/results/depol_block/
# ----------------------------------------------
# Score:  2.638350508650334
# Output files:
# ./validation_results/figs/depol_block/number_of_APs.pdf
# ./validation_results/figs/depol_block/somatic_resp_at_I_maxNumAP.pdf
# ./validation_results/figs/depol_block/somatic_resp_depol_block.pdf
# ./validation_results/figs/depol_block/somatic_resp_at_highest_amp.pdf
# ./validation_results/figs/depol_block/Ith.pdf
# ./validation_results/figs/depol_block/Veq.pdf
# ./validation_results/figs/depol_block/num_of_APs_at_Ith.pdf
# ./validation_results/figs/depol_block/Errors.pdf
# ./validation_results/results/depol_block/depol_block_model_errors.json
# ./validation_results/results/depol_block/depol_block_model_features.json
# ./validation_results/results/depol_block/depol_block_final_score.json
# ./validation_results/results/depol_block/test_log.txt
# ----------------------------------------------
# Result registered successfully!
# cd30731c-8634-4429-9c42-75c5b8a9aad8
# ZScore_avg+penalty = 2.64
# ----------------------------------------------
# Test name:  AP Frequency test
# Test type:  <class 'hippounit.tests.test_APFrequency.APFrequencyTest'>
# ----------------------------------------------
# ----------------------------------------------
# Model name:  Tg_8m
# Model type:  <class 'sciunit_wrapper.ModelLoader'>
# ----------------------------------------------
# ----------------------------------------------
# Score:  2.702225326556304
# Output files:
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.2nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.15nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.1nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_-0.05nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.0nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.05nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.1nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.15nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.2nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.25nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.3nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.35nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.4nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.45nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.5nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.55nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_stim_0.6nA.pdf
# ./validation_results/figs/ap_freq/ap_freq_fI_plot.pdf
# ./validation_results/results/ap_freq/current_amps_spikecounts.json
# ./validation_results/results/ap_freq/ap_freq_summary.json
# ./validation_results/results/ap_freq/test_log.txt
# ----------------------------------------------
# Result registered successfully!
# 4bbc0b70-4940-4523-bbba-2c576ee1b951
# 2.70
# ----------------------------------------------
# Test name:  Depolarization block test
# Test type:  <class 'hippounit.tests.test_DepolarizationBlockTest.DepolarizationBlockTest'>
# ----------------------------------------------
# ----------------------------------------------
# Model name:  Tg_8m
# Model type:  <class 'sciunit_wrapper.ModelLoader'>
# ----------------------------------------------
# The figures are saved in the directory:  ./validation_results/figs/depol_block/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.35000000000000003 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.35000000000000003 nA
# Veq (the equilibrium value during the depolarization block): -22.857681580494926 mV
# Results are saved in the directory:  ./validation_results/results/depol_block/
# ----------------------------------------------
# Score:  2.2459789300168373
# Output files:
# ./validation_results/figs/depol_block/number_of_APs.pdf
# ./validation_results/figs/depol_block/somatic_resp_at_I_maxNumAP.pdf
# ./validation_results/figs/depol_block/somatic_resp_depol_block.pdf
# ./validation_results/figs/depol_block/somatic_resp_at_highest_amp.pdf
# ./validation_results/figs/depol_block/Ith.pdf
# ./validation_results/figs/depol_block/Veq.pdf
# ./validation_results/figs/depol_block/num_of_APs_at_Ith.pdf
# ./validation_results/figs/depol_block/Errors.pdf
# ./validation_results/results/depol_block/depol_block_model_errors.json
# ./validation_results/results/depol_block/depol_block_model_features.json
# ./validation_results/results/depol_block/depol_block_final_score.json
# ./validation_results/results/depol_block/test_log.txt
# ----------------------------------------------
# Result registered successfully!
# 4e8ff990-eaa5-4509-949b-f18f556a0e3e
# ZScore_avg+penalty = 2.25
# ====================== Completed ======================
